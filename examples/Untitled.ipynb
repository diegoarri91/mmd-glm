# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-10, 10, .1)
y1 = x / (1 + np.abs(x))
y2 = -1 / (1 + np.abs(x)) + 1

fig, ax = plt.subplots()
ax.plot(x, y1)
ax.plot(x, y2)
